# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as snb
import os 
import seaborn as sns

# %%
os.getcwd()
data_filepath = "../data/project/"

# %%
data = pd.read_csv(data_filepath+'data_2341.csv')
data.info()
data = data.drop(columns=["Unnamed: 0"])
data.describe();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   A           100 non-null    float64
#  2   B           100 non-null    float64
#  3   C           100 non-null    float64
#  4   D           100 non-null    float64
#  5   E           100 non-null    float64
#  6   F           100 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 5.6 KB

# %%
def plot_nodes(data):
    bins = 100
    plt.figure(figsize=(10, 4))
    plt.subplot(2, 2, 1)
    plt.hist(data["A"], bins=bins)
    plt.title("A")

    plt.subplot(2, 2, 2)
    plt.hist(data["B"], bins=bins)
    plt.title("B")

    plt.subplot(2, 2, 3)
    plt.hist(data["C"], bins=bins)  # clean discrete bins
    plt.title("C")

    plt.subplot(2, 2, 4)
    plt.hist(data["D"], bins=bins)  # clean discrete bins
    plt.title("D")

    plt.tight_layout()
    plt.show()

# %%
data_R0 = pd.read_csv(data_filepath+'data_2341.csv')

data_R0 = data_R0.drop(columns=["Unnamed: 0"])
print(data_R0.describe())
plot_nodes(data=data_R0)
# Out:
#            A           B           C           D           E           F
# count  100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    -2.0    4.200593    0.284938   -1.654063   -1.049414    1.318901
# std      0.0    4.800056    1.046664    3.151592    1.089329    1.505582
# min     -2.0    0.000105   -2.896772  -14.512355   -3.121843   -3.454903
# 25%     -2.0    0.460163   -0.223019   -3.061308   -1.848948    0.414831
# 50%     -2.0    2.469352    0.200956   -0.674629   -1.302229    1.332746
# 75%     -2.0    5.920299    0.713362    0.549317   -0.594837    2.263226
# max     -2.0   21.774576    3.097481    1.977605    2.199979    4.413670

# %%
data_S0 = pd.read_csv(data_filepath+'data_2337.csv')

data_S0 = data_S0.drop(columns=["Unnamed: 0"])
print(data_S0.describe())
plot_nodes(data=data_S0)
# Out:
#                 A           B           C           D           E           F
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     8.738074    3.019664    0.048804   -1.260766   -1.084150    1.145402
# std     18.797596    5.288036    1.213371    2.650159    1.004348    1.560235
# min     -1.094648    0.000430   -4.408296  -12.623601   -2.694079   -4.909498
# 25%      0.883889    0.320376   -0.491129   -2.894710   -1.868100    0.581909
# 50%      2.640008    1.186639   -0.023369   -0.586453   -1.172734    1.187156
# 75%      8.194588    3.469752    0.525582    0.701506   -0.569250    2.211644
# max    158.704905   40.919271    3.368016    2.632421    2.694556    4.472841

# %%
sns.pairplot(data=data), #hue="kdi")
# Out:
# (<seaborn.axisgrid.PairGrid at 0x23bb7924fb0>,)

# %%
sns.jointplot(data=data)

# %%
data_S0.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
test = data_S0[["A", "B"]]
test
# Out:
#             A          B
# 0    0.936817   6.596002
# 1    2.382046  10.572118
# 2   17.247862  40.919271
# 3   -0.035115  17.289082
# 4   13.420300   2.317299
# ..        ...        ...
# 95  28.999698   0.109383
# 96   7.830545   0.007391
# 97   0.392639   1.077998
# 98  15.197308   0.050034
# 99  23.557805   2.162660
#
# [100 rows x 2 columns]
